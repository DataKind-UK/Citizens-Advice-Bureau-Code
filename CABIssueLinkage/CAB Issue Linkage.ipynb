# %%
from CAB_issue_linkage import CAB_issue_linkage
from D3DirectedGraph import publish_js
from IPython.html.widgets import interact, DropdownWidget, FloatSliderWidget

# %%
publish_js()
region = ['North West', 'South East','East Midlands', 'Yorkshire & the Humber',
          'Eastern', 'South West','West Midlands', 'Wales', 'London', 'North East']

# %%
i = interact(CAB_issue_linkage,
         region=region,
         max_number_of_records=DropdownWidget(values=[100,1000,10000,100000,1000000],value=1000),
         max_number_of_nodes=DropdownWidget(values=[10,15,20,25,30],value=15),
         half_life=DropdownWidget(values=[30,90,180,365,365*2,1e9],value=90),
         min_lift=FloatSliderWidget(min=0.5, max=3, step=0.1, value=1.0),
         )
